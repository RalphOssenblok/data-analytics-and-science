# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Ralph Ossenblok\\git\\data-analytics-and-science\\exercises\\exercise 1 - loan prediction problem\\data\\train.csv')

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 16   LP001034    Male      No          1  Not Graduate            No
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 35   LP001106    Male     Yes          0      Graduate            No
# 36   LP001109    Male     Yes          0      Graduate            No
# 42   LP001123    Male     Yes          0      Graduate            No
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 45   LP001137  Female      No          0      Graduate            No
# ...

# %%
df['Credit_History'].fillna(1.0, inplace = True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 35   LP001106    Male     Yes          0      Graduate            No
# 36   LP001109    Male     Yes          0      Graduate            No
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 45   LP001137  Female      No          0      Graduate            No
# 63   LP001213    Male     Yes          1      Graduate            No
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# ...

# %%
m_loanamount = df['LoanAmount'].mean()

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(m_loanamount)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male     NaN          0      Graduate            No
# 2    LP001005    Male     NaN          0      Graduate           Yes
# 4    LP001008    Male     NaN          0      Graduate            No
# 15   LP001032    Male     NaN          0      Graduate            No
# 16   LP001034    Male     NaN          1  Not Graduate            No
# 17   LP001036  Female     NaN          0      Graduate            No
# 18   LP001038    Male     NaN          0  Not Graduate            No
# 20   LP001043    Male     NaN          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 25   LP001066    Male     NaN          0      Graduate           Yes
# 28   LP001086    Male     NaN          0  Not Graduate            No
# 31   LP001095    Male     NaN          0      Graduate            No
# 32   LP001097    Male     NaN          1      Graduate           Yes
# ...

# %%
df['Dependents'].describe()
# Out:
# count     599
# unique      4
# top         0
# freq      345
# Name: Dependents, dtype: object

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df['Self_Employed'].fillna('No', inplace = True)

# %%
df['Loan_Amount_Term'].fillna(360,inplace = True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 104  LP001357    Male     NaN        NaN      Graduate            No
# 120  LP001426    Male     Yes        NaN      Graduate            No
# 126  LP001448     NaN     Yes         3+      Graduate            No
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 188  LP001644     NaN     Yes          0      Graduate           Yes
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 228  LP001760    Male     NaN        NaN      Graduate            No
# 293  LP001945  Female      No        NaN      Graduate            No
# 301  LP001972    Male     Yes        NaN  Not Graduate            No
# 314  LP002024     NaN     Yes          0      Graduate            No
# 332  LP002100    Male      No        NaN      Graduate            No
# ...

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male     NaN          0      Graduate            No
# 2    LP001005    Male     NaN          0      Graduate           Yes
# 4    LP001008    Male     NaN          0      Graduate            No
# 15   LP001032    Male     NaN          0      Graduate            No
# 16   LP001034    Male     NaN          1  Not Graduate            No
# 17   LP001036  Female     NaN          0      Graduate            No
# 18   LP001038    Male     NaN          0  Not Graduate            No
# 20   LP001043    Male     NaN          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 25   LP001066    Male     NaN          0      Graduate           Yes
# 28   LP001086    Male     NaN          0  Not Graduate            No
# 31   LP001095    Male     NaN          0      Graduate            No
# 32   LP001097    Male     NaN          1      Graduate           Yes
# ...
